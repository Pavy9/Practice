# %%
import pandas as pd

# %% [markdown]
# UCI Machine Learning exaple - Airfoil Self-Noise Data Set

# %% [markdown]
# Attribute Information:
#
# This problem has the following inputs:
# 1. Frequency, in Hertzs.
# 2. Angle of attack, in degrees.
# 3. Chord length, in meters.
# 4. Free-stream velocity, in meters per second.
# 5. Suction side displacement thickness, in meters.
#
# The only output is:
# 6. Scaled sound pressure level, in decibels.

# %%
df=pd.read_csv("C:/Users/pavan.kawade/Downloads/airfoil_self_noise.dat",sep="\t",header=None)

# %%
df.head()
# Out:
#       0    1       2     3         4        5
# 0   800  0.0  0.3048  71.3  0.002663  126.201
# 1  1000  0.0  0.3048  71.3  0.002663  125.201
# 2  1250  0.0  0.3048  71.3  0.002663  125.951
# 3  1600  0.0  0.3048  71.3  0.002663  127.591
# 4  2000  0.0  0.3048  71.3  0.002663  127.461

# %%
df.columns=["Frequency","Angle of attack","Chord length","Free-stream velocity","Suction side displacement thickness","Scaled sound pressure level"]

# %%
df.head()
# Out:
#    Frequency  Angle of attack  Chord length  Free-stream velocity  \
# 0        800              0.0        0.3048                  71.3
# 1       1000              0.0        0.3048                  71.3
# 2       1250              0.0        0.3048                  71.3
# 3       1600              0.0        0.3048                  71.3
# 4       2000              0.0        0.3048                  71.3
#
#    Suction side displacement thickness  Scaled sound pressure level
# 0                             0.002663                      126.201
# 1                             0.002663                      125.201
# 2                             0.002663                      125.951
# 3                             0.002663                      127.591
# 4                             0.002663                      127.461

# %%
df.isnull().sum()
# Out:
# Frequency                              0
# Angle of attack                        0
# Chord length                           0
# Free-stream velocity                   0
# Suction side displacement thickness    0
# Scaled sound pressure level            0
# dtype: int64

# %% [markdown]
# No null values found

# %%
from sklearn.model_selection import train_test_split

# %%
X= df.iloc[:,:-1]
y= df.iloc[:,-1]

# %%
X
# Out:
#       Frequency  Angle of attack  Chord length  Free-stream velocity  \
# 0           800              0.0        0.3048                  71.3
# 1          1000              0.0        0.3048                  71.3
# 2          1250              0.0        0.3048                  71.3
# 3          1600              0.0        0.3048                  71.3
# 4          2000              0.0        0.3048                  71.3
# ...         ...              ...           ...                   ...
# 1498       2500             15.6        0.1016                  39.6
# 1499       3150             15.6        0.1016                  39.6
# 1500       4000             15.6        0.1016                  39.6
# 1501       5000             15.6        0.1016                  39.6
# 1502       6300             15.6        0.1016                  39.6
#
#       Suction side displacement thickness
# 0                                0.002663
# 1                                0.002663
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
import seaborn as sns
sns.pairplot (X_train)

# %%
sns.boxplot(X_train["Frequency"])
# Out:
# C:\Users\pavan.kawade\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Frequency'>

# %%
sns.scatterplot(X_train["Frequency"],X_train["Suction side displacement thickness"])
# Out:
# C:\Users\pavan.kawade\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Frequency', ylabel='Suction side displacement thickness'>

# %%
len (df["Scaled sound pressure level"].unique())
# Out:
# 1456

# %%
sns.boxplot(y_train)
# Out:
# C:\Users\pavan.kawade\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Scaled sound pressure level'>

# %%
sns.scatterplot(X_train["Angle of attack"],X_train["Suction side displacement thickness"])
# Out:
# <AxesSubplot:xlabel='Angle of attack', ylabel='Suction side displacement thickness'>

# %%
sns.scatterplot(X_train["Chord length"],X_train["Suction side displacement thickness"])
# Out:
# C:\Users\pavan.kawade\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Chord length', ylabel='Suction side displacement thickness'>

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr = RandomForestRegressor()

# %%
regr
# Out:
# RandomForestRegressor()

# %%
regr.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=regr.predict(X_test)

# %%
len(pred)
# Out:
# 496

# %%
len (y_test)
# Out:
# 496

# %%
from sklearn import metrics
import numpy as np

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.3351021975806459
# Mean Squared Error: 3.3407431158889174
# Root Mean Squared Error: 1.8277699844041966

# %%
#With SVR

# %%
from sklearn.svm import SVR

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train,y_train)
# Out:
# SVR()

# %%
y_pred=regressor.predict(X_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 5.031180693938792
# Mean Squared Error: 41.596476027140575
# Root Mean Squared Error: 6.449533008454223
